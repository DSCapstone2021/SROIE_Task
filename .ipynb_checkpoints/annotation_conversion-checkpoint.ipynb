# %%
import import_ipynb
import json
import numpy as np
import pandas as pd
import torch as pt
import re
import matplotlib.pyplot as plt
from collections import defaultdict
from glob import glob
from classes_funcs import *
# Out:
# importing Jupyter notebook from classes_funcs.ipynb

# %%
input_data_png = 'Appfolio_sample_data/apm_img_0002cf94-5d45-48ef-9ca9-14c7e85ecef1.png'
input_data_boxes = 'Appfolio_sample_data/apm_box_0002cf94-5d45-48ef-9ca9-14c7e85ecef1.csv'
input_data_val_json = 'Appfolio_sample_data/apm_metadata_0002cf94-5d45-48ef-9ca9-14c7e85ecef1.json'

# %%
df = pd.read_csv(input_data_boxes)
df[:5]
# df.iloc[:,1:-1]
pared_df = df.drop(columns=['Unnamed: 0', 'space'])
pared_df
# Out:
#        x0    x2    y0    y2  page_width  page_height  \
# 0     160   301    58   113        2123         2726
# 1     162   288   112   151        2123         2726
# 2    1813  1965   109   138        2123         2726
# 3     198   230   214   250        2123         2726
# 4     249   274   214   250        2123         2726
# ..    ...   ...   ...   ...         ...          ...
# 407  1154  1274  2471  2502        2123         2726
# 408  1278  1282  2471  2502        2123         2726
# 409  1293  1332  2471  2502        2123         2726
# 410  1343  1491  2470  2501        2123         2726
# 411  1148  2018  2627  2663        2123         2726
#
#                                  content  confidence
# 0                                    TXU        0.98
# 1                                 energy        0.99
# 2                             11/02/2020        0.99
# 3                                     MB        0.99
# 4                                     01        0.99
# ..                                   ...         ...
# 407                               DALLAS        0.99
# 408                                    ,        0.99
# 409                                   TX        0.99
# 410                           75265-0638        0.99
# 411  21100072514116000000526200000055259        0.86
#
# [412 rows x 8 columns]

# %%
def convert_box_json(box_csv):
    df = pd.read_csv(box_csv)
    pared_df = df.drop(columns=["Unnamed: 0", "space"])
    dict = {"form": []}
    for idx,text in pared_df.iterrows():
        dict["form"].append({"box": [text["x0"],text["y2"],text["x2"],text["y0"]], "text": text["content"], "label": "", "words": [{"box": [text["x0"],text["x2"],text["y0"],text["y2"]], "text": text["content"]}], "linking": [], "id": idx})
    print(dict)
    
convert_box_json(input_data_boxes)
# Out:
# {'form': [{'box': [160, 113, 301, 58], 'text': 'TXU', 'label': '', 'words': [{'box': [160, 301, 58, 113], 'text': 'TXU'}], 'linking': [], 'id': 0}, {'box': [162, 151, 288, 112], 'text': 'energy', 'label': '', 'words': [{'box': [162, 288, 112, 151], 'text': 'energy'}], 'linking': [], 'id': 1}, {'box': [1813, 138, 1965, 109], 'text': '11/02/2020', 'label': '', 'words': [{'box': [1813, 1965, 109, 138], 'text': '11/02/2020'}], 'linking': [], 'id': 2}, {'box': [198, 250, 230, 214], 'text': 'MB', 'label': '', 'words': [{'box': [198, 230, 214, 250], 'text': 'MB'}], 'linking': [], 'id': 3}, {'box': [249, 250, 274, 214], 'text': '01', 'label': '', 'words': [{'box': [249, 274, 214, 250], 'text': '01'}], 'linking': [], 'id': 4}, {'box': [299, 250, 397, 214], 'text': '011793', 'label': '', 'words': [{'box': [299, 397, 214, 250], 'text': '011793'}], 'linking': [], 'id': 5}, {'box': [417, 250, 497, 214], 'text': '80512', 'label': '', 'words': [{'box': [417, 497, 214, 250], 'text': '80512'}], 'linking': [], 'id': 6}, {'box': [516, 250, 530, 214], 'text': 'B', '